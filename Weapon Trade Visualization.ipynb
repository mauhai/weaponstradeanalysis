# %%
import pandas as pd
import numpy as np

# %%
path = r'~/Devproj/weaponstradeanalysis/data/TIV-Import-USA-1950-2015.csv'
df = pd.read_csv(path)
#extract current country
country = df.columns.values.tolist()[0].split('TIV of arms exports to ')[1].split(', 1950-2015')[0]
#downsize
df = df.ix[9:]
#get rid of column
df = df.drop(df.columns[[0]],axis =1)
df
# Out:
#                   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 9                        NaN      1950.0      1951.0      1952.0      1953.0
# 10                    Angola         NaN         NaN         NaN         NaN
# 11                 Australia         NaN         NaN         NaN         NaN
# 12                   Austria         NaN         NaN         NaN         NaN
# 13                  Bulgaria         NaN         NaN         NaN         NaN
# 14                    Canada        23.0        52.0       262.0        52.0
# 15                      Chad         NaN         NaN         NaN         NaN
# 16            Czech Republic         NaN         NaN         NaN         NaN
# 17                   Denmark         NaN         NaN         NaN         NaN
# 18                     Egypt         NaN         NaN         NaN         NaN
# 19                    France         NaN         NaN         NaN         NaN
# ...

# %%
df = df.set_index((df['Unnamed: 1']))
df.columns = df.iloc[0]
df = df[1:] #take the data less the header row
df = df.drop(df.columns[0], axis=1)
df = df.reset_index()
df

# %%
# Out:
# nan                Unnamed: 1  1950.0  1951.0  1952.0  1953.0  1954.0  1955.0  \
# 0                      Angola     NaN     NaN     NaN     NaN     NaN     NaN
# 1                   Australia     NaN     NaN     NaN     NaN     NaN     NaN
# 2                     Austria     NaN     NaN     NaN     NaN     NaN     NaN
# 3                    Bulgaria     NaN     NaN     NaN     NaN     NaN     NaN
# 4                      Canada    23.0    52.0   262.0    52.0    37.0    32.0
# 5                        Chad     NaN     NaN     NaN     NaN     NaN     NaN
# 6              Czech Republic     NaN     NaN     NaN     NaN     NaN     NaN
# 7                     Denmark     NaN     NaN     NaN     NaN     NaN     NaN
# 8                       Egypt     NaN     NaN     NaN     NaN     NaN     NaN
# 9                      France     NaN     NaN     NaN     NaN     NaN     NaN
# 10              Germany (FRG)     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
df
# Out:
# nan                                            NaN  1950.0  1951.0  1952.0  \
# Unnamed: 1
# Angola                                      Angola     NaN     NaN     NaN
# Australia                                Australia     NaN     NaN     NaN
# Austria                                    Austria     NaN     NaN     NaN
# Bulgaria                                  Bulgaria     NaN     NaN     NaN
# Canada                                      Canada    23.0    52.0   262.0
# Chad                                          Chad     NaN     NaN     NaN
# Czech Republic                      Czech Republic     NaN     NaN     NaN
# Denmark                                    Denmark     NaN     NaN     NaN
# Egypt                                        Egypt     NaN     NaN     NaN
# France                                      France     NaN     NaN     NaN
# Germany (FRG)                        Germany (FRG)     NaN     NaN     NaN
# ...
